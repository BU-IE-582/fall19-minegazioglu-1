# %% [markdown]
# # IE 582 Statistical Learning for Data Mining - Homework 5

# %% [markdown]
# _Mine Gazioğlu_

# %% [markdown]
# _8 January 2020_

# %%
# Importing necessary libraries

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra
import matplotlib.pyplot as plt # visualization
import matplotlib.pylab as plb # visualization
import seaborn as sns # visualization
import warnings # ignore deprecation warnings etc.
warnings.filterwarnings("ignore")
import time # dealing with time data
from datetime import datetime, timedelta # dealing with time data
import xlrd # read data in .xlsx format
from mpl_toolkits.mplot3d import Axes3D # Matplotlib 3d plot

# %%
# Load data with pandas
# train
x_train = pd.read_excel("582\\HW5\\UWave_TRAIN\\x_train.xlsx")
y_train = pd.read_excel("582\\HW5\\UWave_TRAIN\\y_train.xlsx")
z_train = pd.read_excel("582\\HW5\\UWave_TRAIN\\z_train.xlsx")
# test
x_test = pd.read_excel("582\\HW5\\uWaveGestureLibrary_X_TEST\\x_test.xlsx")
y_test = pd.read_excel("582\\HW5\\uWaveGestureLibrary_Y_TEST\\y_test.xlsx")
z_test = pd.read_excel("582\\HW5\\uWaveGestureLibrary_Z_TEST\\z_test.xlsx")

# %%
# Rename columns of train and test datasets
datasets = [x_train,y_train,z_train,x_test,y_test,z_test]
for dataset in datasets:
    dataset.rename(columns = {"Column2":"class"},inplace = True)
    dataset.columns.values[1:] = ["column_" + str(i) for i in range(2,317,1)]

# %% [markdown]
# ## Tasks

# %% [markdown]
# **a) Read the data and visualize at least one instance (all axes) from each class and try to relate the shape
# (time series) you see with the gestures shown in Figure 1 (this is just for fun, sometimes it is good to
# start with data visualization to understand what is going on). A 3D scatter plot would be interesting. Note
# that this is not a position information. The acceleration information for each axis is provided in the files.**

# %% [markdown]
# Below are the 8 gestures' visual representations as we plot the scatter plots we can compare the observations to below figures

# %%
# Read and plot the image
img = (Image.open("gestures.png"))
plt.imshow(img);

# %%
# There are 8 classes(gestures)- we will create 8 scatter plots
sorted(x_train["class"].unique())
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# **Create gesture velocity & location dataframes for each of the 8 classes**

# %%
# We are given acceleration information that needs to be converted to velocity then positional information
# take all columns except "class"
train_columns = x_train.columns.values[1:]

## Below dataframes(velocity and location) per axis for all 8 gestures are created 
## Per gesture 6 dataframes are created
## The positional dataframes for all 3 axes will be used to plot gestures
## Integral of acceleration dataframe via numpy's cumsum function is calculated
## Then the cumulative sum of the velocity dataframe is computed to get positional information

# Gesture 1
# x_train 
x_train_velocity_1 = pd.DataFrame()
x_train_location_1 = pd.DataFrame()
x_gesture_1 = x_train[x_train["class"] == 1]
for column in train_columns:
    x_train_velocity_1[column] = np.cumsum(x_gesture_1[column])
    x_train_location_1[column] = np.cumsum(x_train_velocity_1[column])
#y_train
y_train_velocity_1 = pd.DataFrame()
y_train_location_1 = pd.DataFrame()
y_gesture_1 = y_train[y_train["class"] == 1]
for column in train_columns:
    x_train_velocity_1[column] = np.cumsum(y_gesture_1[column])
    y_train_location_1[column] = np.cumsum(x_train_velocity_1[column])
#z_train
z_train_velocity_1 = pd.DataFrame()
z_train_location_1 = pd.DataFrame()
z_gesture_1 = z_train[z_train["class"] == 1]
for column in train_columns:
    z_train_velocity_1[column] = np.cumsum(z_gesture_1[column])
    z_train_location_1[column] = np.cumsum(z_train_velocity_1[column])
####    
# Gesture 2
# x_train 
x_train_velocity_2 = pd.DataFrame()
x_train_location_2 = pd.DataFrame()
x_gesture_2 = x_train[x_train["class"] == 2]
for column in train_columns:
    x_train_velocity_2[column] = np.cumsum(x_gesture_2[column])
    x_train_location_2[column] = np.cumsum(x_train_velocity_2[column])
#y_train
y_train_velocity_2 = pd.DataFrame()
y_train_location_2 = pd.DataFrame()
y_gesture_2 = y_train[y_train["class"] == 2]
for column in train_columns:
    x_train_velocity_2[column] = np.cumsum(y_gesture_2[column])
    y_train_location_2[column] = np.cumsum(x_train_velocity_2[column])
#z_train
z_train_velocity_2 = pd.DataFrame()
z_train_location_2 = pd.DataFrame()
z_gesture_2 = z_train[z_train["class"] == 2]
for column in train_columns:
    z_train_velocity_2[column] = np.cumsum(z_gesture_2[column])
    z_train_location_2[column] = np.cumsum(z_train_velocity_2[column])    
####
# Gesture 3
# x_train 
x_train_velocity_3 = pd.DataFrame()
x_train_location_3 = pd.DataFrame()
x_gesture_3 = x_train[x_train["class"] == 3]
for column in train_columns:
    x_train_velocity_3[column] = np.cumsum(x_gesture_3[column])
    x_train_location_3[column] = np.cumsum(x_train_velocity_3[column])
#y_train
y_train_velocity_3 = pd.DataFrame()
y_train_location_3 = pd.DataFrame()
y_gesture_3 = y_train[y_train["class"] == 3]
for column in train_columns:
    x_train_velocity_3[column] = np.cumsum(y_gesture_3[column])
    y_train_location_3[column] = np.cumsum(x_train_velocity_3[column])
#z_train
z_train_velocity_3 = pd.DataFrame()
z_train_location_3 = pd.DataFrame()
z_gesture_3 = z_train[z_train["class"] == 3]
for column in train_columns:
    z_train_velocity_3[column] = np.cumsum(z_gesture_3[column])
    z_train_location_3[column] = np.cumsum(z_train_velocity_3[column])
####
# Gesture 4
# x_train 
x_train_velocity_4 = pd.DataFrame()
x_train_location_4 = pd.DataFrame()
x_gesture_4 = x_train[x_train["class"] == 4]
for column in train_columns:
    x_train_velocity_4[column] = np.cumsum(x_gesture_4[column])
    x_train_location_4[column] = np.cumsum(x_train_velocity_4[column])
#y_train
y_train_velocity_4 = pd.DataFrame()
y_train_location_4 = pd.DataFrame()
y_gesture_4 = y_train[y_train["class"] == 4]
for column in train_columns:
    x_train_velocity_4[column] = np.cumsum(y_gesture_4[column])
    y_train_location_4[column] = np.cumsum(x_train_velocity_4[column])
#z_train
z_train_velocity_4 = pd.DataFrame()
z_train_location_4 = pd.DataFrame()
z_gesture_4 = z_train[z_train["class"] == 4]
for column in train_columns:
    z_train_velocity_4[column] = np.cumsum(z_gesture_4[column])
    z_train_location_4[column] = np.cumsum(z_train_velocity_4[column])
####
# Gesture 5
# x_train 
x_train_velocity_5 = pd.DataFrame()
x_train_location_5 = pd.DataFrame()
x_gesture_5 = x_train[x_train["class"] == 5]
for column in train_columns:
    x_train_velocity_5[column] = np.cumsum(x_gesture_5[column])
    x_train_location_5[column] = np.cumsum(x_train_velocity_5[column])
#y_train
y_train_velocity_5 = pd.DataFrame()
y_train_location_5 = pd.DataFrame()
y_gesture_5 = y_train[y_train["class"] == 5]
for column in train_columns:
    x_train_velocity_5[column] = np.cumsum(y_gesture_5[column])
    y_train_location_5[column] = np.cumsum(x_train_velocity_5[column])
#z_train
z_train_velocity_5 = pd.DataFrame()
z_train_location_5 = pd.DataFrame()
z_gesture_5 = z_train[z_train["class"] == 5]
for column in train_columns:
    z_train_velocity_5[column] = np.cumsum(z_gesture_5[column])
    z_train_location_5[column] = np.cumsum(z_train_velocity_5[column])
####
# Gesture 6
# x_train 
x_train_velocity_6 = pd.DataFrame()
x_train_location_6 = pd.DataFrame()
x_gesture_6 = x_train[x_train["class"] == 6]
for column in train_columns:
    x_train_velocity_6[column] = np.cumsum(x_gesture_6[column])
    x_train_location_6[column] = np.cumsum(x_train_velocity_6[column])
#y_train
y_train_velocity_6 = pd.DataFrame()
y_train_location_6 = pd.DataFrame()
y_gesture_6 = y_train[y_train["class"] == 6]
for column in train_columns:
    x_train_velocity_6[column] = np.cumsum(y_gesture_6[column])
    y_train_location_6[column] = np.cumsum(x_train_velocity_6[column])
#z_train
z_train_velocity_6 = pd.DataFrame()
z_train_location_6 = pd.DataFrame()
z_gesture_6 = z_train[z_train["class"] == 6]
for column in train_columns:
    z_train_velocity_6[column] = np.cumsum(z_gesture_6[column])
    z_train_location_6[column] = np.cumsum(z_train_velocity_6[column])
####
# Gesture 7
# x_train 
x_train_velocity_7 = pd.DataFrame()
x_train_location_7 = pd.DataFrame()
x_gesture_7 = x_train[x_train["class"] == 7]
for column in train_columns:
    x_train_velocity_7[column] = np.cumsum(x_gesture_7[column])
    x_train_location_7[column] = np.cumsum(x_train_velocity_7[column])
#y_train
y_train_velocity_7 = pd.DataFrame()
y_train_location_7 = pd.DataFrame()
y_gesture_7 = y_train[y_train["class"] == 7]
for column in train_columns:
    x_train_velocity_7[column] = np.cumsum(y_gesture_7[column])
    y_train_location_7[column] = np.cumsum(x_train_velocity_7[column])
#z_train
z_train_velocity_7 = pd.DataFrame()
z_train_location_7 = pd.DataFrame()
z_gesture_7 = z_train[z_train["class"] == 7]
for column in train_columns:
    z_train_velocity_7[column] = np.cumsum(z_gesture_7[column])
    z_train_location_7[column] = np.cumsum(z_train_velocity_7[column])
####
# Gesture 8
# x_train 
x_train_velocity_8 = pd.DataFrame()
x_train_location_8 = pd.DataFrame()
x_gesture_8 = x_train[x_train["class"] == 8]
for column in train_columns:
    x_train_velocity_8[column] = np.cumsum(x_gesture_8[column])
    x_train_location_8[column] = np.cumsum(x_train_velocity_8[column])
#y_train
y_train_velocity_8 = pd.DataFrame()
y_train_location_8 = pd.DataFrame()
y_gesture_8 = y_train[y_train["class"] == 8]
for column in train_columns:
    x_train_velocity_8[column] = np.cumsum(y_gesture_8[column])
    y_train_location_8[column] = np.cumsum(x_train_velocity_8[column])
#z_train
z_train_velocity_8 = pd.DataFrame()
z_train_location_8 = pd.DataFrame()
z_gesture_8 = z_train[z_train["class"] == 8]
for column in train_columns:
    z_train_velocity_8[column] = np.cumsum(z_gesture_8[column])
    z_train_location_8[column] = np.cumsum(z_train_velocity_8[column])

# %%
# Merge location dataframes for all classes for future purposes
# Also add class column back to positional dataframes

#x_train
x_train_location_list = [x_train_location_1,x_train_location_2,x_train_location_3,x_train_location_4,
                         x_train_location_5,x_train_location_6,x_train_location_7,x_train_location_8]
for i,dataframe in enumerate(x_train_location_list):
    dataframe["class"] = i+1
total_location_x_train = pd.concat(x_train_location_list,axis = 0)

#y_train
y_train_location_list = [y_train_location_1,y_train_location_2,y_train_location_3,y_train_location_4,
                         y_train_location_5,y_train_location_6,y_train_location_7,y_train_location_8]
for i,dataframe in enumerate(y_train_location_list):
    dataframe["class"] = i+1
total_location_y_train = pd.concat(y_train_location_list,axis = 0)

#z_train
z_train_location_list = [z_train_location_1,z_train_location_2,z_train_location_3,z_train_location_4,
                         z_train_location_5,z_train_location_6,z_train_location_7,z_train_location_8]
for i,dataframe in enumerate(z_train_location_list):
    dataframe["class"] = i+1
total_location_z_train = pd.concat(z_train_location_list,axis = 0)

# %% [markdown]
# **Plot Gestures**

# %% [markdown]
# Below first instance for each class is used to plot the gesture.

# %% [markdown]
# **Gesture 1**

# %%
# Plot gesture using 3D scatterplot
fig = plt.figure()
ax = Axes3D(fig)

ax.set_title("Gesture 1",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")



ax.scatter(x_train_location_1.iloc[0,:-1],y_train_location_1.iloc[0,:-1],z_train_location_1.iloc[0,:-1],alpha = 0.5)
plt.show()
img = (Image.open("gesture_1.png"))
plt.imshow(img);

# %% [markdown]
# **Gesture 2**

# %%
# Plot gesture using 3D scatterplot
fig = plt.figure()
ax = Axes3D(fig)

ax.set_title("Gesture 2",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(x_train_location_2.iloc[0,:-1],y_train_location_2.iloc[0,:-1],z_train_location_2.iloc[0,:-1],alpha = 0.5)
plt.show()
img = (Image.open("gesture_2.png"))
plt.imshow(img);

# %% [markdown]
# **Gesture 3**

# %%
# Plot gesture using 3D scatterplot
fig = plt.figure()
ax = Axes3D(fig)

ax.set_title("Gesture 3",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(x_train_location_3.iloc[0,:-1],y_train_location_3.iloc[0,:-1],z_train_location_3.iloc[0,:-1],alpha = 0.5)
plt.show()
img = (Image.open("gesture_3.png"))
plt.imshow(img);

# %% [markdown]
# **Gesture 4**

# %%
# Plot gesture using 3D scatterplot
fig = plt.figure()
ax = Axes3D(fig)

ax.set_title("Gesture 4",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(x_train_location_4.iloc[0,:-1],y_train_location_4.iloc[0,:-1],z_train_location_4.iloc[0,:-1],alpha = 0.5)
plt.show()
img = (Image.open("gesture_4.png"))
plt.imshow(img);

# %% [markdown]
# **Gesture 5**

# %%
# Plot gesture using 3D scatterplot
fig = plt.figure()
ax = Axes3D(fig)

ax.set_title("Gesture 5",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(x_train_location_5.iloc[0,:-1],y_train_location_5.iloc[0,:-1],z_train_location_5.iloc[0,:-1],alpha = 0.5)
plt.show()
img = (Image.open("gesture_5.png"))
plt.imshow(img);

# %% [markdown]
# **Gesture 6**

# %%
# Plot gesture using 3D scatterplot
fig = plt.figure()
ax = Axes3D(fig)

ax.set_title("Gesture 6",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(x_train_location_6.iloc[0,:-1],y_train_location_6.iloc[0,:-1],z_train_location_6.iloc[0,:-1],alpha = 0.5)
plt.show()
img = (Image.open("gesture_6.png"))
plt.imshow(img);

# %% [markdown]
# **Gesture 7**

# %%
# Plot gesture using 3D scatterplot
fig = plt.figure()
ax = Axes3D(fig)

ax.set_title("Gesture 7",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(x_train_location_7.iloc[0,:-1],y_train_location_7.iloc[0,:-1],z_train_location_7.iloc[0,:-1],alpha = 0.5)
plt.show()
img = (Image.open("gesture_7.png"))
plt.imshow(img);

# %% [markdown]
# **Gesture 8**

# %%
# Plot gesture using 3D scatterplot
fig = plt.figure()
ax = Axes3D(fig)

ax.set_title("Gesture 8",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(x_train_location_8.iloc[0,:-1],y_train_location_8.iloc[0,:-1],z_train_location_8.iloc[0,:-1],alpha = 0.5)
plt.show()
img = (Image.open("gesture_8.png"))
plt.imshow(img);

# %% [markdown]
# **Discussion on part a:**  As can be seen from the gesture plots, the observations plotted do not perfectly showcase the gestures given in the article. This is acceptable because the observations are supplied from 8 users who can not display immaculate shapes with hands. In our case while some figures are alike their class and are distunguishable as gesture 8 and 7,the others could be hard to match for an observer, however, when inspected upclose they resemble their representation in the article. Also, we have used just one observation to display the gesture. Other instances can result in better similarities.

# %% [markdown]
# **b) Propose two distance measures for computing similarity between two time series. For each distance
# measure alternative, you are expected to evaluate the performance of two clustering approaches: k-means
# and hierarchical clustering. Since you are asked to work with distances, you need to use a modified
# version of k-means which is called the k-medoids approach. What is the difference between the k-means
# and k-medoids? In which condition(s) are they equivalent?**

# %% [markdown]
# **Find distance matrices**

# %% [markdown]
# Manhattan and Euclidean distances are chosen for computing similarity between two time series

# %%
# First concatenate x,y,z coordinates for train datasets columnwise
train = pd.concat([x_train,y_train,z_train],axis = 1)

# %%
#remove duplicate class columns created by concatenation

m1 = train.columns.str.startswith('class')
m2 = train.columns.str.split('.').str[0].duplicated()
train = train.loc[:, ~m1 | ~m2]

# %% [markdown]
# **Scale data before finding distance matrices**

# %%
# Clustering algorithms are sensitive to scaling
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
ss.fit(train)
train = ss.transform(train)
train = pd.DataFrame(train)

# %% [markdown]
# **Euclidean and Manhattan Distance Matrices**

# %%
from scipy.spatial import distance_matrix # p=1 for manhattan and p=2 for euclidean from minkowski eq.
#Euclidean
euclidean_matrix = pd.DataFrame(distance_matrix(train.values, train.values,p = 2))
#Manhattan
manhattan_matrix = pd.DataFrame(distance_matrix(train.values, train.values,p = 1))

# %% [markdown]
# **What is the difference between the k-means and k-medoids?:**<br>
# The k-medoids algorithm is a clustering algorithm related to the k-means algorithm. Both the k-means and k-medoids algorithms are partitional (breaking the dataset up into groups). They are both trying to minimize the distance between points of the same cluster and a particular point which is the center of that cluster. In contrast to the k-means algorithm, k-medoids algorithm chooses points as centers that belong to the dastaset. K-means attempts to minimize the total squared error, while k-medoids minimizes the sum of dissimilarities between points labeled to be in a cluster and a point designated as the center of that cluster. In contrast to the k-means algorithm, k-medoids chooses datapoints as centers ( medoids or exemplars).K-medoids is more robust to noise and outliers compared to K-means.<br>
# **In which condition(s) are they equivalent?:**<br>
# Since we take the most centrally located object in a cluster rather than taking the mean values of the object in a cluster as the reference point, when mean and most centrally located point will be equal, k-means and k-medoids will be equivalent.

# %% [markdown]
# **c) For each distance measure alternative and clustering approach, you need to decide the number of clusters.
# Decide on the number of clusters to use for each clustering approach. Recall that there are alternative
# approaches to compute the distance between the clusters for hierarchical clustering. Consider at least two
# alternatives.**

# %% [markdown]
# **Determining Optimal Number of Clusters**

# %% [markdown]
# A variety of measures have been proposed to evaluate clustering results.Such methods include elbow method, gap statistic, silhouette method etc... I will try elbow method for this task. Also, I tried to plot dendrograms for hierarchical clustering.A dendrogram is a type of tree diagram showing relationships between similar sets of data. They are frequently used in biology to show clustering between genes or samples, but they can represent any type of grouped data.However, there were too many points for a dendrogram and it was far from interpretable.<br>
#
# The elbow method, in which the sum of squares at each number of clusters is calculated and graphed, and the user looks for a change of slope from steep to shallow (an elbow) to determine the optimal number of clusters. This method is inexact, but still potentially helpful.

# %% [markdown]
# **Hierarchical Clustering**

# %% [markdown]
# **Elbow Method**

# %% [markdown]
# **Using 2 alternative linkage(the method to determine the distance between clusters) methods**

# %% [markdown]
# Let's use single and complete linkage.In **single linkage** hierarchical clustering, the distance between two clusters is defined as the shortest distance between two points in each cluster. In **complete linkage** hierarchical clustering, the distance between two clusters is defined as the longest distance between two points in each cluster.

# %% [markdown]
# **Euclidean-Single Linkage**

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(affinity='euclidean',linkage = "single")
visualizer = KElbowVisualizer(cluster, k=(1,24),timings = False,locate_elbow = True,metric = "distortion")

visualizer.fit(euclidean_matrix)        # Fit the data to the visualizer
visualizer.show()

# %% [markdown]
# **Manhattan-Single Linkage**

# %%
from yellowbrick.cluster import KElbowVisualizer
cluster = AgglomerativeClustering(affinity='euclidean', linkage='single')
visualizer = KElbowVisualizer(cluster, k=(1,24),timings = False,locate_elbow = True,metric = "distortion")

visualizer.fit(manhattan_matrix)        # Fit the data to the visualizer
visualizer.show()

# %% [markdown]
# **Euclidean-Complete Linkage**

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(affinity='euclidean',linkage = "complete")
visualizer = KElbowVisualizer(cluster, k=(1,24),timings = False,locate_elbow = True,metric = "distortion")

visualizer.fit(euclidean_matrix)        # Fit the data to the visualizer
visualizer.show()

# %% [markdown]
# **Manhattan-Complete Linkage**

# %%
from yellowbrick.cluster import KElbowVisualizer
cluster = AgglomerativeClustering(affinity='euclidean', linkage='complete')
visualizer = KElbowVisualizer(cluster, k=(1,24),timings = False,locate_elbow = True,metric = "distortion")

visualizer.fit(manhattan_matrix)        # Fit the data to the visualizer
visualizer.show()

# %% [markdown]
# **K-medoids**

# %% [markdown]
# **Euclidean**

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn_extra.cluster import KMedoids
kmedoids = KMedoids(n_clusters = 10,random_state=0)
visualizer = KElbowVisualizer(kmedoids, k=(1,24),timings = False,locate_elbow = True,metric = "distortion")

visualizer.fit(euclidean_matrix)        # Fit the data to the visualizer
visualizer.show()

# %% [markdown]
# **Manhattan**

# %%
from yellowbrick.cluster import KElbowVisualizer
kmedoids = KMedoids(n_clusters = 10,random_state=0)
visualizer = KElbowVisualizer(kmedoids, k=(1,24),timings = False,locate_elbow = True,metric = "distortion")

visualizer.fit(manhattan_matrix)        # Fit the data to the visualizer
visualizer.show()

# %% [markdown]
# We got different number of optimal clusters for each approach. Only k-medoids clustering with distance metric euclidean was able to capture the true cluster number. Especially hierarchical clustering with single linkage did not give close numbers to the true cluster number. <br>
# Also, one important thing to note is we used StandardScaler to scale our features other scalers could have yielded different number of optimal clusters

# %% [markdown]
# **d) Suppose, we decide to use the clustering results to do prediction on the test data. Report the accuracies
# for all the approaches you proposed. What is your conclusion?**

# %% [markdown]
# We will have total of 6 models with 6 predictions and will measure the accuracy for each one but first, we need to calculate distance matrices for the test data the same way we did for the training data.

# %% [markdown]
# **Calculate distance matrices for test data**

# %%
#conserve class data as we will use it to compare the results later
test_classes = x_test["class"]

# %%
# First concatenate x,y,z coordinates for train datasets
test = pd.concat([x_test,y_test,z_test],axis = 1)

#remove duplicate class columns created by concatenation
m1 = test.columns.str.startswith('class')
m2 = test.columns.str.split('.').str[0].duplicated()
test = test.loc[:, ~m1 | ~m2]

# scaling
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(train)
test = ss.transform(test)
test = pd.DataFrame(test)

# distance matrix calculation

from scipy.spatial import distance_matrix # p=1 for manhattan and p=2 for euclidean
#Euclidean
euclidean_matrix = pd.DataFrame(distance_matrix(test.values, test.values,p =2))
manhattan_matrix = pd.DataFrame(distance_matrix(test.values, test.values,p =1))

# %% [markdown]
# **1. Hierarchical Clustering - Euclidean - Single Linkage**

# %%
# For hierarchical clustering euclidean distance we determined optimal number of clusters with elbow method to be 5
# Euclidean - Single Linkage
cluster = AgglomerativeClustering(n_clusters = 5,affinity='euclidean', linkage='single')
hier_euc_single = cluster.fit_predict(euclidean_matrix)
hier_euc_single += 1
# Calculate accuracy
from sklearn.metrics import accuracy_score
accuracy_score_1 = accuracy_score(test_classes,hier_euc_single)
print(accuracy_score_1)
# Out:
# 0.12199888330541597

# %% [markdown]
# **2. Hierarchical Clustering - Manhattan - Single Linkage**

# %%
cluster = AgglomerativeClustering(n_clusters = 6,affinity='euclidean', linkage='single')
hier_man_single = cluster.fit_predict(manhattan_matrix)
hier_man_single += 1
# Calculate accuracy
from sklearn.metrics import accuracy_score
accuracy_score_2 = accuracy_score(test_classes,hier_man_single)
print(accuracy_score_2)
# Out:
# 0.12311557788944724

# %% [markdown]
# **3. Hierarchical Clustering - Euclidean - Complete Linkage**

# %%
cluster = AgglomerativeClustering(n_clusters = 9,affinity='euclidean', linkage='complete')
hier_euc_complete = cluster.fit_predict(euclidean_matrix)
hier_euc_complete  = hier_euc_complete +1
# Calculate accuracy
from sklearn.metrics import accuracy_score
accuracy_score_3 = accuracy_score(test_classes,hier_euc_complete)
print(accuracy_score_3)
# Out:
# 0.28671133445002794

# %% [markdown]
# **4. Hierarchical Clustering - Manhattan - Complete Linkage**

# %%
cluster = AgglomerativeClustering(n_clusters = 7,affinity='euclidean', linkage='complete')
hier_man_complete = cluster.fit_predict(manhattan_matrix)
hier_man_complete = hier_man_complete + 1
# Calculate accuracy
from sklearn.metrics import accuracy_score
accuracy_score_4 = accuracy_score(test_classes,hier_man_complete)
print(accuracy_score_4)
# Out:
# 0.1457286432160804

# %% [markdown]
# **5. k-medoids - Euclidean**

# %%
# Euclidean
kmedoids = KMedoids(n_clusters = 8,random_state=0)
kmedoids_euclidean = kmedoids.fit_predict(euclidean_matrix)
kmedoids_euclidean = kmedoids_euclidean +1
# Calculate accuracy
from sklearn.metrics import accuracy_score
accuracy_score_5 = accuracy_score(test_classes,kmedoids_euclidean)
print(accuracy_score_5)
# Out:
# 0.1702959240647683

# %% [markdown]
# **6. k-medoids - Manhattan**

# %%
# Manhattan
kmedoids = KMedoids(n_clusters = 10,random_state=0)
kmedoids_manhattan = kmedoids.fit_predict(manhattan_matrix)
kmedoids_manhattan =  kmedoids_manhattan + 1
# Calculate accuracy
from sklearn.metrics import accuracy_score
accuracy_score_6 = accuracy_score(test_classes,kmedoids_manhattan)
print(accuracy_score_6)
# Out:
# 0.010329424902289224

# %% [markdown]
# We got the best accuracy score from hierarchical-euclidean-complete linkage clustering. However, all accuracy scores were pretty low which is expected considering they did not give the right amount of cluster number and the predictions are compared to actual class information that has 8 classes. For example for our best performance model gives 28% percent right classes but it has an additional class (9) classes when our actual target has 8 classes. I was expecting best performance from k-medoids-euclidean since it had the exact same number of classes as the original target but it turned out to give second best accuracy score.

# %% [markdown]
# **e) For the clustering approach that provides the best accuracy on the test data, draw the time series for each
# cluster on a scatter plot. In other words, you will have a time series plot for each cluster where the plot
# has all the time series from one cluster plotted over each other. Also, plot the average of the observations
# at each time point for each cluster on the same plot with different color. This can be interpreted as the
# cluster centroid which is expected to show the cluster prototype.**

# %% [markdown]
# Best accuracy providing approach was k-medoids with euclidean distance.For this approach we have chosen optimal cluster value to be 8. Now we will plot 8 scatter plots for each cluster. For this we will append our predictions for euclidean k- medoids to test sets as if it was our classes.

# %%
# Drop class column from dataframes
x_test.drop("class",axis = 1,inplace = True)
y_test.drop("class",axis = 1,inplace = True)
z_test.drop("class",axis = 1,inplace = True)

# %%
# Add new_class column that contains predictions from euclidean k-medoids approach
x_test["new_class"] = hier_euc_complete
y_test["new_class"] = hier_euc_complete
z_test["new_class"] = hier_euc_complete

# %% [markdown]
# **Plot Class 1**

# %%
# Separate dataframes into classes
# x
class_1_test_x = x_test[x_test["new_class"] == 1]
# y
class_1_test_y = y_test[y_test["new_class"] == 1]
# z
class_1_test_z = z_test[z_test["new_class"] == 1]


# Take the average of the observations for class 1 and plot it with a different color on the same plot
class_1_test_x_avg = class_1_test_x.drop("new_class",axis = 1).mean()

class_1_test_y_avg = class_1_test_y.drop("new_class",axis = 1).mean()

class_1_test_z_avg = class_1_test_z.drop("new_class",axis = 1).mean()

fig, ax = plt.subplots(1, 1, figsize=(10, 10), subplot_kw={'projection': '3d'})
ax.set_title("Class 1",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(class_1_test_x_avg,class_1_test_y_avg,class_1_test_z_avg, alpha = 1,color = "yellow")
ax.scatter(class_1_test_x.iloc[:,:-1],class_1_test_y.iloc[:,:-1],class_1_test_z.iloc[:,:-1],alpha = 0.01)

# %% [markdown]
# **Plot Class 2**

# %%
# Separate dataframes into classes
# x
class_2_test_x = x_test[x_test["new_class"] == 2]
# y
class_2_test_y = y_test[y_test["new_class"] == 2]
# z
class_2_test_z = z_test[z_test["new_class"] == 2]


# Take the average of the observations for class 1 and plot it with a different color on the same plot
class_2_test_x_avg = class_2_test_x.drop("new_class",axis = 1).mean()

class_2_test_y_avg = class_2_test_y.drop("new_class",axis = 1).mean()

class_2_test_z_avg = class_2_test_z.drop("new_class",axis = 1).mean()

fig, ax = plt.subplots(1, 1, figsize=(10, 10), subplot_kw={'projection': '3d'})
ax.set_title("Class 2",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(class_2_test_x_avg,class_2_test_y_avg,class_2_test_z_avg, alpha = 1,color = "yellow")
ax.scatter(class_2_test_x.iloc[:,:-1],class_2_test_y.iloc[:,:-1],class_2_test_z.iloc[:,:-1],alpha = 0.01)

# %% [markdown]
# **Plot Class 3**

# %%
# Separate dataframes into classes
# x
class_3_test_x = x_test[x_test["new_class"] == 3]
# y
class_3_test_y = y_test[y_test["new_class"] == 3]
# z
class_3_test_z = z_test[z_test["new_class"] == 3]


# Take the average of the observations for class 1 and plot it with a different color on the same plot
class_3_test_x_avg = class_3_test_x.drop("new_class",axis = 1).mean()

class_3_test_y_avg = class_3_test_y.drop("new_class",axis = 1).mean()

class_3_test_z_avg = class_3_test_z.drop("new_class",axis = 1).mean()

fig, ax = plt.subplots(1, 1, figsize=(10, 10), subplot_kw={'projection': '3d'})
ax.set_title("Class 3",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(class_3_test_x_avg,class_3_test_y_avg,class_3_test_z_avg, alpha = 1,color = "yellow")
ax.scatter(class_3_test_x.iloc[:,:-1],class_3_test_y.iloc[:,:-1],class_3_test_z.iloc[:,:-1],alpha = 0.01)

# %% [markdown]
# **Plot Class 4**

# %%
# Separate dataframes into classes
# x
class_4_test_x = x_test[x_test["new_class"] == 4]
# y
class_4_test_y = y_test[y_test["new_class"] == 4]
# z
class_4_test_z = z_test[z_test["new_class"] == 4]


# Take the average of the observations for class 1 and plot it with a different color on the same plot
class_4_test_x_avg = class_4_test_x.drop("new_class",axis = 1).mean()

class_4_test_y_avg = class_4_test_y.drop("new_class",axis = 1).mean()

class_4_test_z_avg = class_4_test_z.drop("new_class",axis = 1).mean()

fig, ax = plt.subplots(1, 1, figsize=(10, 10), subplot_kw={'projection': '3d'})
ax.set_title("Class 4",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(class_4_test_x_avg,class_4_test_y_avg,class_4_test_z_avg, alpha = 1,color = "yellow")
ax.scatter(class_4_test_x.iloc[:,:-1],class_4_test_y.iloc[:,:-1],class_4_test_z.iloc[:,:-1],alpha = 0.01)

# %% [markdown]
# **Plot Class 5**

# %%
# Separate dataframes into classes
# x
class_5_test_x = x_test[x_test["new_class"] == 5]
# y
class_5_test_y = y_test[y_test["new_class"] == 5]
# z
class_5_test_z = z_test[z_test["new_class"] == 5]


# Take the average of the observations for class 1 and plot it with a different color on the same plot
class_5_test_x_avg = class_5_test_x.drop("new_class",axis = 1).mean()

class_5_test_y_avg = class_5_test_y.drop("new_class",axis = 1).mean()

class_5_test_z_avg = class_5_test_z.drop("new_class",axis = 1).mean()

fig, ax = plt.subplots(1, 1, figsize=(10, 10), subplot_kw={'projection': '3d'})
ax.set_title("Class 5",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(class_5_test_x_avg,class_5_test_y_avg,class_5_test_z_avg, alpha = 1,color = "yellow")
ax.scatter(class_5_test_x.iloc[:,:-1],class_5_test_y.iloc[:,:-1],class_5_test_z.iloc[:,:-1],alpha = 0.01)

# %% [markdown]
# **Plot Class 6**

# %%
# Separate dataframes into classes
# x
class_6_test_x = x_test[x_test["new_class"] == 6]
# y
class_6_test_y = y_test[y_test["new_class"] == 6]
# z
class_6_test_z = z_test[z_test["new_class"] == 6]


# Take the average of the observations for class 1 and plot it with a different color on the same plot
class_6_test_x_avg = class_6_test_x.drop("new_class",axis = 1).mean()

class_6_test_y_avg = class_6_test_y.drop("new_class",axis = 1).mean()

class_6_test_z_avg = class_6_test_z.drop("new_class",axis = 1).mean()

fig, ax = plt.subplots(1, 1, figsize=(10, 10), subplot_kw={'projection': '3d'})
ax.set_title("Class 6",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(class_6_test_x_avg,class_6_test_y_avg,class_6_test_z_avg, alpha = 1,color = "yellow")
ax.scatter(class_6_test_x.iloc[:,:-1],class_6_test_y.iloc[:,:-1],class_6_test_z.iloc[:,:-1],alpha = 0.01,depthshade = True)

# %% [markdown]
# **Plot Class 7**

# %%
# Separate dataframes into classes
# x
class_7_test_x = x_test[x_test["new_class"] == 7]
# y
class_7_test_y = y_test[y_test["new_class"] == 7]
# z
class_7_test_z = z_test[z_test["new_class"] == 7]


# Take the average of the observations for class 1 and plot it with a different color on the same plot
class_7_test_x_avg = class_7_test_x.drop("new_class",axis = 1).mean()

class_7_test_y_avg = class_7_test_y.drop("new_class",axis = 1).mean()

class_7_test_z_avg = class_7_test_z.drop("new_class",axis = 1).mean()

fig, ax = plt.subplots(1, 1, figsize=(10, 10), subplot_kw={'projection': '3d'})
ax.set_title("Class 7",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")


ax.scatter(class_7_test_x.iloc[:,:-1],class_7_test_y.iloc[:,:-1],class_7_test_z.iloc[:,:-1],alpha = 0.01)
ax.scatter(class_7_test_x_avg.astype("float"), class_7_test_y_avg.astype("float"), class_7_test_z_avg.astype("float"), alpha = 1,color = "yellow")

# %% [markdown]
# **Plot Class 8**

# %%
# Separate dataframes into classes
# x
class_8_test_x = x_test[x_test["new_class"] == 8]
# y
class_8_test_y = y_test[y_test["new_class"] == 8]
# z
class_8_test_z = z_test[z_test["new_class"] == 8]


# Take the average of the observations for class 1 and plot it with a different color on the same plot
class_8_test_x_avg = class_8_test_x.drop("new_class",axis = 1).mean()

class_8_test_y_avg = class_8_test_y.drop("new_class",axis = 1).mean()

class_8_test_z_avg = class_8_test_z.drop("new_class",axis = 1).mean()

fig, ax = plt.subplots(1, 1, figsize=(10, 10), subplot_kw={'projection': '3d'})
ax.set_title("Class 8",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(class_8_test_x_avg,class_8_test_y_avg,class_8_test_z_avg, alpha = 1,color = "yellow")
ax.scatter(class_8_test_x.iloc[:,:-1],class_8_test_y.iloc[:,:-1],class_8_test_z.iloc[:,:-1],alpha = 0.01)

# %% [markdown]
# **Plot Class 9**

# %%
# Separate dataframes into classes
# x
class_8_test_x = x_test[x_test["new_class"] == 9]
# y
class_8_test_y = y_test[y_test["new_class"] == 9]
# z
class_8_test_z = z_test[z_test["new_class"] == 9]


# Take the average of the observations for class 1 and plot it with a different color on the same plot
class_8_test_x_avg = class_8_test_x.drop("new_class",axis = 1).mean()

class_8_test_y_avg = class_8_test_y.drop("new_class",axis = 1).mean()

class_8_test_z_avg = class_8_test_z.drop("new_class",axis = 1).mean()

fig, ax = plt.subplots(1, 1, figsize=(10, 10), subplot_kw={'projection': '3d'})
ax.set_title("Class 9",fontsize = 20)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(class_8_test_x_avg,class_8_test_y_avg,class_8_test_z_avg, alpha = 1,color = "yellow")
ax.scatter(class_8_test_x.iloc[:,:-1],class_8_test_y.iloc[:,:-1],class_8_test_z.iloc[:,:-1],alpha = 0.01)

# %% [markdown]
# I have drawn the time series for each cluster on a scatter plot.There are a total of 9 clusters. We also took the mean of clusters and and drew cluster centroid. Cluster Centroid (or simply centroid) is the mean of a cluster, its values are the coordinate-wise average of the data points in this cluster. The cluster centroid is implied to show class prototype. For classes 8 and 9 we can see it resembles classes 7 and 8. The other classes are not as distiguishable.
